# %% [markdown]
# <a href="https://colab.research.google.com/github/godqhrgo7849/Oracle/blob/main/Ex6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day - 2026.08.24
#
#
#
# 1.   함수 선언과 호출
# 2.   람다 함수
# 3.   모듈 개요

# %%
# 함수 선언 호출
# 함수 - 재사용 가능한 프로구램, 명령 덩어리 - 내장함수, 사용자 정의 함수
'''
변수 < 함수 < 모듈(파일단위) < 라이브러리(패키지-폴더단위)
내장함수 - 파이썬에서 자동으로 호출해서 사용하는 함수
사용자정의 함수 - 직접 정의하고 호출하는 함수
모듈
 - 표준 모듈 : 파이썬에 이미 지정된 모듈들.
              math, random, csv, sqlite
 - 외장 모듈 : 설치가 필요한 모듈들. pip install ~
              pandas, numpy, sklearn, seaborn
'''
# 함수의 형식 * 중요부분 두가지
# Python - def 사용 > def 함수명 + (인자): //인자가 없을 수도 있음 void
                      #   명령문
                      # return >  값 > 계산식 > 변수 > 함수 등이 올 수 있음
# Out:
# '\n변수 < 함수 < 모듈(파일단위) < 라이브러리(패키지-폴더단위)\n내장함수 - 파이썬에서 자동으로 호출해서 사용하는 함수 \n사용자정의 함수 - 직접 정의하고 호출하는 함수 \n모듈 \n - 표준 모듈 : 파이썬에 이미 지정된 모듈들. \n              math, random, csv, sqlite\n - 외장 모듈 : 설치가 필요한 모듈들. pip install ~ \n              pandas, numpy, sklearn, seaborn \n'

# %%
def sum(a,b):
  result = a+b
  return result

a = sum(3,4)
print(a)

def helloWorld():
  print("Hello World")

helloWorld()
# Out:
# 7
# Hello World

# %%
def dan():
  num = int(input("출력하고자 하는 구구단을 입력하시오. : "))
  a = [f"{num}*{i}={num*i}" for i in range(1, 10)]
  print(*a, sep ="\n")

dan()
# Out:
# 출력하고자 하는 구구단을 입력하시오. : 5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45

# %%
def cal(x, y):
    print(f" {x} + {y} = {x+y}")
    print(f" {x} - {y} = {x-y}")
    print(f" {x} * {y} = {x*y}")
    print(f" {x} / {y} = {x/y:.2f}")
    print(f" {x} % {y} = {x%y}")
cal(10, 5)
# Out:
#  10 + 5 = 15
#  10 - 5 = 5
#  10 * 5 = 50
#  10 / 5 = 2.00
#  10 % 5 = 0

# %%
# 퀴즈
# 숫자만큼 다음과 같은 형태로 별모양을 출력하는 함수를 정의한 후 호출하여라

def starprint(star):
  a = '*'
  for i in range(1, star+1):
    print(a * i)
j = int(input('별의 갯수를 입력하세요 :'))
starprint(j)
# Out:
# 별의 갯수를 입력하세요 :6
# *
# **
# ***
# ****
# *****
# ******

# %%
def starprint(star):
  a = '*'
  stars = (a * i for i in range(1, star+1))
  print(*stars, sep ="\n")
j = int(input('별의 갯수를 입력하세요 :'))
starprint(j)
# Out:
# 별의 갯수를 입력하세요 :8
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********

# %%
# 함수의 반환값
# return 되는 데이터가 여러개인 경우 > 튜플
# return 데이터1, 데이터2,  ... > (데이터1,2,...)

def hello(user):
  return f'{user}님 좋은 하루 되세요'
hello # 기본 호출을 했을 경우 프린트문이 없기 때문에 no docstring
print(hello('홍길동')) # 따로 프린트문을 사용해 값을 넣어줬기 때문에 출력 값이 나온다.
# Out:
# 홍길동님 좋은 하루 되세요

# %%
def hello1(user,msg):
  result = f'{user}님 환영합니다.'
  result1 = f'{user}님, {msg}\n'
  return result,result1
print(hello1('홍길동','좋은 하루  되세요.'))
text = hello1('고길동','감사합니다.')
print(type(text),text[0])
# Out:
# ('홍길동님 환영합니다.', '홍길동님, 좋은 하루  되세요.\n')
# <class 'tuple'> 고길동님 환영합니다.

# %%
# 인자의 합을 구하는 함수 정의
def calc(x=0, y=0,z=0):
  return f'{x} + {y} + {z} = {x+y+z}'
print(calc(150,267,8))
# Out:
# 150 + 267 + 8 = 425

# %%
def mul(n, m=1):
  return print(f'{n} x {m} = {n*m}')
mul(7)
mul(7,8)
# Out:
# 7 x 1 = 7
# 7 x 8 = 56

# %%
# 초기값이 지정된 인자랑 초기값이 없는 인자가 함께 정의된 함수
def starPrint(n, mark='* '):
    for i in range(1, n+1):
        print( mark * i)
    print("="*40)
starPrint(3)
starPrint(4, '!')
# Out:
# *
# * *
# * * *
# ...
# !
# !!
# !!!
# !!!!
# ...

# %%
# 퀴즈
# 아래의 함수를 호출하여 메세지가 출력되도록 함수를 정의하여라

# 함수 정의
def say_myself(name,old,man=True):
  if man == True:
    print(f' 나의 이름은 {name} 입니다. \n 나이는 {old}입니다. \n 남자입니다.')
  else:
    print(f' 나의 이름은 {name} 입니다. \n 나이는 {old}입니다. \n 여자입니다.')

say_myself('김철수',20)
say_myself('이민정',15,False)
# Out:
#  나의 이름은 김철수 입니다.
#  나이는 20입니다.
#  남자입니다.
#  나의 이름은 이민정 입니다.
#  나이는 15입니다.
#  여자입니다.

# %%
# 가변인자 - 인자의 수가 정해져 있지 않음
# def 함수명(*args)
      # args는 튜플로 작동
      # 명령문
# 함수명() => 빈튜플 ()
# 함수명(값1) => 튜플 1개 (값1, )
# 함수명(값1, 값2...) => 튜플 1개 (값1, 값2...)

def studentName(*args):
  print(f"전체 수강생 목록 > {args},총인원수 => {len(args)}\n")
  if len(args):
    for member in args:
      print(member)
  else :
    print('수강생이 없습니다.\n')
studentName()

studentName('고길동')
studentName('고길동','김민정','홍길동','파라미터')
# Out:
# 전체 수강생 목록 > (),총인원수 => 0
#
# 수강생이 없습니다.
#
# 전체 수강생 목록 > ('고길동',),총인원수 => 1
#
# 고길동
# 전체 수강생 목록 > ('고길동', '김민정', '홍길동', '파라미터'),총인원수 => 4
#
# 고길동
# 김민정
# 홍길동
# 파라미터

# %%
# 퀴즈
# *args를 이용하여 매개변수로 받은 학생 이름에 따라 알래와 같이 출력되도록 함수를 정의하여라
# 이때 매개변수가 없는 경우에는 '학생이 없습니다' 메세지를 출력한다.
def studentName2(*args):
  if len(args):
    for i in range(len(args)):
      print(f'{i+1}번째 학생 : {args[i]}')
  else:
    print("학생이 없습니다.")
  print()
studentName2()
studentName2('홍길동')
studentName2('홍길동','이순신','이몽룡')
# Out:
# 학생이 없습니다.
#
# 1번째 학생 : 홍길동
#
# 1번째 학생 : 홍길동
# 2번째 학생 : 이순신
# 3번째 학생 : 이몽룡

# %%
# 일반인자, 초기값이 있는 인자, 가변인자 함께 정의되어 있는 함수 정의
# def 함수명(인자1, 인자2, 가변인자):
      # 명령문
def introduce(stname,grade=1,*info):
  print(f'학생명 : {stname}')
  print(f'학년 : {grade}')
  for i in info:
    print(i)
  print()

introduce('김철수')
introduce('홍길동',3,'국어','영어','수학')
# Out:
# 학생명 : 김철수
# 학년 : 1
#
# 학생명 : 홍길동
# 학년 : 3
# 국어
# 영어
# 수학

# %%
# 퀴즈
# 첫 번째 인자의 값이 'min'이면 다음 인자의 숫자 중 최대값을 출력하고
# 첫 번째 인자의 값이 'max'이면 다음 인자의 숫자 중 최소값을 출력하여라
# 이때 전달하는 숫자의 갯수는 가변으로 한다.

def min_max_number(index, *nums):
  if index == 'min':
    print(f'최소값은 : {min(nums)}')
  elif index == 'max':
    print(f'최대값은 : {max(nums)}')
  else :
    print("오류")

min_max_number('더하기',10,56,-90,1000)
min_max_number('min',10,56,-90,1000)
min_max_number('max',10,56,-90,1000)
# Out:
# 오류
# 최소값은 : -90
# 최대값은 : 1000

# %%
# 키워드아규먼트 **kwargs

# kwargs => keyword arguments
# def 함수명(**kwargs):
#     kwargs는 딕셔너리
#     명령문
# 함수명(키변수=값, ...)

def intro(**kwargs):
  print(type(kwargs),len(kwargs))
  print(kwargs)
  for k,v in kwargs.items():
    print(f"{k}=> {v}")
intro()
intro(userId="admin", userName="홍길동")
intro(userId="manager", userName="고길동", userAge=22)
# Out:
# <class 'dict'> 0
# {}
# <class 'dict'> 2
# {'userId': 'admin', 'userName': '홍길동'}
# userId=> admin
# userName=> 홍길동
# <class 'dict'> 3
# {'userId': 'manager', 'userName': '고길동', 'userAge': 22}
# userId=> manager
# userName=> 고길동
# userAge=> 22

# %%
# 일반인자 , *args, **kwargs
# def 함수명(일반인자, *args, **kwargs):
      # args는 튜플, kwargs는 딕셔너리
      # 명령문
def make_user(userName, *args, **kwargs):
    print(f"userName = {userName}")
    print(f"args = {args}")
    print(f"kwargs = {kwargs}")
    print()
make_user('홍길동')
make_user('홍길동', 12, '경영학과')
make_user('홍길동', 12, '경영학과', address='부산', mobile='010-1234-5678')
# Out:
# userName = 홍길동
# args = ()
# kwargs = {}
#
# userName = 홍길동
# args = (12, '경영학과')
# kwargs = {}
#
# userName = 홍길동
# args = (12, '경영학과')
# kwargs = {'address': '부산', 'mobile': '010-1234-5678'}

# %%
# 람다 함수
# 변수 lambda 인자 : 명령문
# map(람다식, 리스트 & 튜플), filter(람다식, 리스트 & 튜플)

# 일반함수 스타일
def avg(kor, eng, math):
  return round((kor+eng+math)/3,3)

print(avg(10,45,60)) # 38.333

# 람다 함수 스타일

avg_f = lambda kor, eng, math : round((kor+eng+math)/3,3)
print(avg_f(10,45,60))
# Out:
# 38.333
# 38.333

# %%
# 퀴즈
# 첫 글자를 제외한 나머지 글자를 '*'로 표시하는 람다 함수를 정의하여라
f1 = lambda txt:print(txt[0]+'*'*len(txt[1:]))
f1('홍길동')
f1('asdfawer')
f1('백합과장미')
f1('빅데이터인공지능')
# Out:
# 홍**
# a*******
# 백****
# 빅*******

# %%
# 퀴즈
# 국어,영어,수학 3과목의 합과 평균을 구하는 람다 함수를 정의하여라
f2 = lambda kor, eng, math:print(f"국어:{kor} 영어:{eng} 수학:{math} 총점:{kor+eng+math} 평균:{(kor+eng+math)/3:.2f}")
f2(100, 45, 67)
f2(87, 45, 55)
# Out:
# 국어:100 영어:45 수학:67 총점:212 평균:70.67
# 국어:87 영어:45 수학:55 총점:187 평균:62.33

# %%
# filter(함수명 & 람다식, 리스트 & 튜플) > filter 객체 > 반복문 & list()
# 리스트/튜플로 부터 함수명 & 람다식을 저용해서 true인 데이터만 출력

# 특정 리스트에서 양수만 추출하는 함수 정의
# 일반 함수 스타일
def filter_ps(numlist):
  result_list = []
  for num in numlist:
    if num > 0:
      result_list.append(num)
  return result_list
print(filter_ps([1, -3, 2, 0, -5, 6]))

# 람다 함수 스타일
print(list(filter(lambda x:x>0, [1, -3, 2, 0, -5, 6])))
# Out:
# [1, 2, 6]
# [1, 2, 6]

# %%
# filter() + 일반함수
def posNum(num):
    return num > 0
numlist = [ 10, 55, -90, -78, 100, 0, -9]
print(filter(posNum, numlist)) # <filter object at 0x000002414ACA6590>
print(list(filter(posNum, numlist))) # [10, 55, 100]
for num in filter(posNum, numlist):
    print(num)
print()

# 람다함수
numlist = [ 10, 55, -90, -78, 100, 0, -9]
print(list(filter(lambda num:num>0, numlist)))
# Out:
# ...
# [10, 55, 100]
# 10
# 55
# 100
#
# [10, 55, 100]

# %%
# 퀴즈
# filter() 함수를 이용하여 다음 리스트에서 글자 수가 4글자 이상인 담어만 골라
# 새로운 리스트로 생성하는 코드를 작성하여라
words = ["apple", "it", "python", "ai", "banana", "go", "developer", "sql"]
print(list(filter(lambda word:len(word)>=4, words)))
# Out:
# ['apple', 'python', 'banana', 'developer']

# %%
# 퀴즈
# filter() 함수를 이용하여 다음 문자열에서 숫자만 리스트로
# 만들어 출력하여라. (isdigit()이용)

message = 'ab4690cfvg342가1나다0'
print(list(filter(lambda x:x.isdigit(), message)))
# Out:
# ['4', '6', '9', '0', '3', '4', '2', '1', '0']

# %%
# map() - 리스트의 제곱을 구해서 새로운 리스트로 만들기

# map(함수 & 람다식, 리스트 & 튜플 & 문자열) > map 객체 > 리스트화 & 반복문

numlist2 = [1,2,3,4]

# 제곱을 구하는 함수 정의
def power_fn1(mylist):
  result = []
  for i in mylist:
    result.append(i**2)
  return result
print(power_fn1(numlist2))

# map() 사용할 제곱을 출력하는 함수 정의
def power_f2(value):
  return value**2
print(power_f2(3))
print(map(power_f2,numlist2))
print(list(map(power_f2,numlist2)))

# 람닿마수 이용
f_multy = lambda x:x**2
print(f_multy(2))
print(list(map(lambda x:x**2,numlist2)))
# Out:
# [1, 4, 9, 16]
# 9
# ...
# [1, 4, 9, 16]
# 4
# [1, 4, 9, 16]

# %%
# 서로 다른 리스트에서 같은 위치의 데이터의 곱으로 새로운 리스트 생성
# map + 일반 함수

def make_multy(x,y):
  return x*y
list1 = [2,3,7]
list2 = [4,5,9]
print(list(map(make_multy,list1,list2)))
print(list1*3)
# Out:
# [8, 15, 63]
# [2, 3, 7, 2, 3, 7, 2, 3, 7]

# %%
print(list(map(lambda x,y:x*y,list1,list2)))
# Out:
# [8, 15, 63]

# %%
# 퀴즈
# 4개의 리스트 각 아이템 요소가 '-'로 연결되어 출력되도록 하여라
# 최종 결과는 리스트로 저장되어야 하며 map() 함수를 활용한다

num_list = [100, 200, 300, 400]
name_list = ['길동', '동미', '미영', '영철']
gender_list = ['남','여','여','남']
address_list = ['서울','대전','부산','대구']

print(list(map(lambda num, name, gender, address : f"{num}-{name}-{gender}-{address}",num_list,name_list,gender_list,address_list)))
# Out:
# ['100-길동-남-서울', '200-동미-여-대전', '300-미영-여-부산', '400-영철-남-대구']

# %%
# 모듈 불러오기
# import 모듈명
# 모듈명.함수(옵션)
# import 모듈명 as 별칭
# 별칭명.함수(옵션)
# from 모듈명 import 함수명
# 함수(옵션)

import math
help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#         The result is between 0 and pi.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#         The result is between -pi/2 and pi/2.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     cbrt(x, /)
#         Return the cube root of x.
#
# ...

# %%
import math as m
print(m.pi)
print(m.sin(15))
# Out:
# 3.141592653589793
# 0.6502878401571168

# %%
import random
print(random.__doc__)
print(random.random())
print(random.randint(1,10))
# Out:
# Random variable generators.
#
#     bytes
#     -----
#            uniform bytes (values between 0 and 255)
#
#     integers
#     --------
#            uniform within range
#
#     sequences
#     ---------
#            pick random element
#            pick random sample
#            pick weighted random sample
#            generate random permutation
#
#     distributions on the real line:
#     ------------------------------
#            uniform
#            triangular
#            normal (Gaussian)
#            lognormal
#            negative exponential
#            gamma
#            beta
#            pareto
#            Weibull
#
#     distributions on the circle (angles 0 to 2pi)
#     ---------------------------------------------
#            circular uniform
#            von Mises
#
#     discrete distributions
#     ----------------------
#            binomial
#
#
# General notes on the underlying Mersenne Twister core generator:
#
# * The period is 2**19937-1.
# ...

# %%
print(random.randint(1,5))
print([random.randint(0,1) for i in range(10)])
print([random.randrange(11) for i in range(10)])
print([random.random() for i in range(3)])
print([round(random.random(),2) for i in range(3)])
print([round(random.uniform(-5,5),1) for i in range(10)])
# Out:
# 3
# [0, 0, 0, 0, 0, 1, 1, 0, 1, 0]
# [2, 3, 1, 10, 4, 4, 4, 7, 10, 9]
# [0.7517560127678019, 0.9781721709199709, 0.011864275707999639]
# [0.58, 0.62, 0.85]
# [-0.7, 3.9, -4.4, -4.6, -1.2, 0.6, 1.4, 3.4, 2.6, 4.7]

# %%
# 리스트안에서 뽑기
import random
student_list = ['철수', '영희', '길동', '미미', '영철', '은정', '흥민']
print(random.sample(student_list,2))
random.shuffle(student_list)
print(student_list)
# Out:
# ['영철', '길동']
# ['철수', '흥민', '영희', '길동', '영철', '은정', '미미']

# %%
import random as rm
lotto = []
for i in range(6):
  temp = random.randint(1,45)
  lotto.append(temp)
lotto = sorted(lotto)
print(lotto)
# Out:
# [1, 1, 2, 27, 31, 37]

# %%
def make_lotto1():
    lotto_list = [ random.randint(1, 45) for _ in range(6)]
    lotto_list = sorted(lotto_list)
    print(f'로또 번호 : {lotto_list}')
make_lotto1()
# Out:
# 로또 번호 : [13, 15, 26, 42, 44, 45]

# %%
def make_lotto():
  lotto_list = []
  while True:
    if len(lotto_list) == 6:
      break
    temp = random.randint(1, 45)
    if temp not in lotto_list:
      lotto_list.append(temp)
  return sorted(lotto_list)
print(make_lotto())
print(make_lotto())
# Out:
# [4, 11, 13, 20, 21, 39]
# [1, 2, 3, 38, 40, 45]

# %%
# 퀴즈
# 아래의 학생 리스트에서 일주일(월~금) 청소당번 2명을 뽑아서 출력하여라

import random as rd

def choice(daylist,studentlist):
  for i in daylist:
    choice = random.sample(studentlist,2)
    print(f'{i} 청소 당번은? {' , '.join(choice)}')
  print()
stList = [ '김철수', '홍길동', '기대주', '이동백','하민수', '김영희', '소민주', '신은수']
choice(['월','화','수','목','금'],stList)
# Out:
# 월 청소 당번은? 김철수 , 하민수
# 화 청소 당번은? 하민수 , 소민주
# 수 청소 당번은? 이동백 , 하민수
# 목 청소 당번은? 홍길동 , 김영희
# 금 청소 당번은? 홍길동 , 김영희

# %%
# 퀴즈
# 무작위로 퀴즈를 출제하도록 프로그래밍 하여라.

def quiz(chs):
  quizl = random.choice(chs)
  print(f"문제 : {quizl['question']}")
  for i in quizl['options']:
    print('\t'+i)
  d = int(input("정답을 입력하세요 : "))
  if d == quizl['answer']:
    print("정답입니다.")
  else:
    print("틀렸습니다.")

quiz_list = [{"question": "파이썬에서 난수를 생성하는 모듈은?","options": ["1. math", "2. random", "3. time", "4. os"],"answer": 2},
            {"question": "리스트에서 요소를 무작위로 하나 뽑는 함수는?","options": ["1. shuffle", "2. randint", "3. choice", "4. sample"],"answer": 3},
            {"question": "파이썬의 실행 결과값이 항상 짝수로 반올림되는 함수는?","options": ["1. round", "2. ceil", "3. floor", "4. trunc"],"answer": 1}]
quiz(quiz_list)
# Out:
# 문제 : 파이썬의 실행 결과값이 항상 짝수로 반올림되는 함수는?
# 	1. round
# 	2. ceil
# 	3. floor
# 	4. trunc
# 정답을 입력하세요 : 1
# 정답입니다.
